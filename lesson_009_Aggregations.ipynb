# %% [markdown]
# <a href="https://colab.research.google.com/github/shrikantkhule100-ux/PORTFOLIO/blob/main/lesson_009_Aggregations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#manual way
#scroes = [80,90,70,85,95]
#total = 0
#for s in scroes:
 ###print("manual Average", average)


  #profetional way
import numpy as np
scores =np.array([80,90,70,85,95])
average=np.mean(scores)
print("the minimum value is:",np.min(scores))
print("the maximum value is:",np.max(scores))
print("the average:",average)
# Out:
# the minimum value is: 70
# the maximum value is: 95
# the average: 84.0
