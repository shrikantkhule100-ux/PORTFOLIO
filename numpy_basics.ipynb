# %% [markdown]
# <a href="https://colab.research.google.com/github/shrikantkhule100-ux/PORTFOLIO/blob/main/numpy_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
college_list=[10,20,30]
ai_array = np.array([10,20,30])
result= ai_array+5
print("orignal Data:", ai_array)
print("Data after AI proccessing(+5 to all):",result)
# Out:
# orignal Data: [10 20 30]
# Data after AI proccessing(+5 to all): [15 25 35]
