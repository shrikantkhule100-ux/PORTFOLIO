# %% [markdown]
# <a href="https://colab.research.google.com/github/shrikantkhule100-ux/PORTFOLIO/blob/main/matrix_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
matrix = np.array([[1,2,3],[4,5,6]])
print("your first AI Matrix")
print(matrix)

print("shape of the matrix :",matrix.shape)
# Out:
# your first AI Matrix
# [[1 2 3]
#  [4 5 6]]
# shape of the matrix : (2, 3)
