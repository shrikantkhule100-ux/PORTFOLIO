# %% [markdown]
# <a href="https://colab.research.google.com/github/shrikantkhule100-ux/PORTFOLIO/blob/main/ai_logic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
score=60
if score>=80:
  print("AI decision: student is qulified for AI specialization !")
else:
  print("AI Decision : keep practising the fundamentals.")
# Out:
# AI Decision : keep practising the fundamentals.
